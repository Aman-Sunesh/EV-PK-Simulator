# %%
from evpklib import exp

# %%
lab = exp.Experiment.loadfrom_study(study_id="theoph", json_path="/home/hetorex/Coding/EV-PK-Simulator/backend/studies_manifest.json")

# %%
lab.fit(model="two")
# Out:
# /home/hetorex/Coding/EV-PK-Simulator/evpklib/evpklib/two_compartment_model.py:72: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(

# %%
lab.export_report("./a.pdf")
